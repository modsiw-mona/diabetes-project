# %% [markdown]
# ## Data extraction
#
# ### By:
# Sofia Arango
#
# ### Date:
# 2026-08-15
#
# ### Description:
# Notebook used to download the dataset and select the columns that are going to be used in the project.

# %% [markdown]
# ## 📚 Import  libraries

# %%
# base libraries for data science
from pathlib import Path

import pandas as pd

# %% [markdown]
# ## 💾 Load data

# %%
file_path = "/Users/sof/Documents/maestria/diabetes-project/data/01_raw/diabetes.csv"
diabetes_df = pd.read_csv(file_path, low_memory=False)
diabetes_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 994 entries, 0 to 993
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               986 non-null    float64
#  1   Glucose                   990 non-null    float64
#  2   BloodPressure             989 non-null    float64
#  3   SkinThickness             987 non-null    float64
#  4   Insulin                   986 non-null    float64
#  5   BMI                       992 non-null    float64
#  6   DiabetesPedigreeFunction  989 non-null    float64
#  7   Age                       991 non-null    float64
#  8   Outcome                   975 non-null    float64
# dtypes: float64(9)
# memory usage: 70.0 KB

# %%
diabetes_df.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 253          0.0     86.0           68.0           32.0      0.0  35.8
# 261          3.0    141.0            0.0            0.0      0.0  30.0
# 544          1.0     88.0           78.0           29.0     76.0  32.0
# 184          4.0    141.0           74.0            0.0      0.0  27.6
# 555          7.0    124.0           70.0           33.0    215.0  25.5
# 375         12.0    140.0           82.0           43.0    325.0  39.2
# 290          0.0     78.0           88.0           29.0     40.0  36.9
# 753          0.0    181.0           88.0           44.0    510.0  43.3
# 889          2.0    129.0           84.0            0.0      0.0  28.0
# 349          5.0      0.0           80.0            NaN      0.0  41.0
#
#      DiabetesPedigreeFunction   Age  Outcome
# 253                     238.0  25.0      0.0
# 261                     761.0  27.0      1.0
# 544                     365.0  29.0      0.0
# ...

# %% [markdown]
# ## 📊 Data info

# %%
diabetes_df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='str')

# %%
columns_to_use = [
    "Pregnancies",
    "Glucose",
    "BloodPressure",
    "SkinThickness",
    "Insulin",
    "BMI",
    "DiabetesPedigreeFunction",
    "Age",
    "Outcome",
]
